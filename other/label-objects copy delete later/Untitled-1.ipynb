# %%
# import classifier.classifier as classifier
import renderer.renderer as renderer
from PIL import Image
import os
from transformers import pipeline
from PIL import Image





# renderer.render_meshes_from_scene('./renderer/cafeteria.glb', './render')
# remove render folder if it exists
if os.path.exists('./render'):
    os.system('rm -rf ./render')
renderer.render_meshes_from_scene('./classroom.glb', './render')


# --------------------------------------------------------------------

directory_path = 'render'
all_entries = os.listdir(directory_path)
files = [f for f in all_entries if os.path.isfile(os.path.join(directory_path, f))]
files = sorted(files)

# %%
captioner = pipeline("image-to-text", model="Salesforce/blip-image-captioning-large")

for file in files:
    image = Image.open("./render/" + file)
    result = captioner(image)
    result = result[0]['generated_text']
    # remove 'a' ot 'an' from the beginning of the sentence
    if result.startswith('a '):
        result = result[2:]
    if result.startswith('an '):
        result = result[3:]
    
    # remove ' with a white background'
    result = result.replace ('on a white background', '')
    result = result.replace('with a white background', '')
    result = result.replace('a white background', '')
    result = result.replace('white background', '')
    result = result.strip()

    print(file, result)
# Out:
# /home/furkan/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# rendered_mesh_0_0.png there is a red book with a gray cover on it
# rendered_mesh_0_1.png there is a red book with a gray cover on it
# rendered_mesh_0_2.png there is a red box with a black lid
# rendered_mesh_0_3.png there is a red book sitting on top of a white table
# rendered_mesh_10_0.png there is a red book with a gray cover on it
# rendered_mesh_10_1.png there is a red book with a gray cover on it
# rendered_mesh_10_2.png there is a red box with a black lid
# rendered_mesh_10_3.png there is a red book sitting on top of a white table
# rendered_mesh_11_0.png close up of a black box
# rendered_mesh_11_1.png close up of a black box
# rendered_mesh_11_2.png close up of a black box
# rendered_mesh_11_3.png close up of a black object
# rendered_mesh_12_0.png there is a small house with a brown roof and a brown roof
# rendered_mesh_12_1.png there is a bed with a brown blanket and a window
# rendered_mesh_12_2.png there is a room with a bed and a window in it
# rendered_mesh_12_3.png there is a small house with a brown roof and a brown door
# rendered_mesh_13_0.png there is a chocolate bar with a chocolate bar in it
# rendered_mesh_13_1.png there is a chocolate bar with a chocolate bar in it
# rendered_mesh_13_2.png there is a black object
# rendered_mesh_13_3.png there is a black object
# rendered_mesh_14_0.png there is a brown piece of wood on a white surface
# rendered_mesh_14_1.png close up of a brown plastic door handle
# rendered_mesh_14_2.png there is a black board  with a black border
# rendered_mesh_14_3.png there is a black television screen sitting on a white surface
# rendered_mesh_15_0.png there is a laptop computer sitting on a table with a keyboard
# rendered_mesh_15_1.png there is a black shelf with a book and a black book case
# rendered_mesh_15_2.png there is a laptop and a keyboard on a desk
# rendered_mesh_15_3.png there is a computer monitor and a keyboard on a desk
# rendered_mesh_16_0.png close up of a white tube
# rendered_mesh_16_1.png close up of a white tube
# rendered_mesh_16_2.png close up of a black tube
# rendered_mesh_16_3.png there is a black tube
# rendered_mesh_17_0.png there is a red plastic block with a black top
# rendered_mesh_17_1.png there is a red brick that is on a white surface
# rendered_mesh_17_2.png there is a small black brush that is on a white surface
# rendered_mesh_17_3.png there is a chocolate bar that is sitting on a white surface
# rendered_mesh_18_0.png there is a brown box with a lid
# rendered_mesh_18_1.png there is a brown box with a lid
# rendered_mesh_18_2.png there is a black dresser with a drawer on top of it
# rendered_mesh_18_3.png there is a black dresser with a drawer on top of it
# rendered_mesh_19_0.png close up of a chocolate ice cream bar
# rendered_mesh_19_1.png close up of a chocolate ice cream bar
# rendered_mesh_19_2.png there is a black handle
# rendered_mesh_19_3.png there is a black object with a yellow strip on it
# rendered_mesh_1_0.png there is a black and white photo of a kite flying in the sky
# rendered_mesh_1_1.png there is a black and white photo of a kite flying in the sky
# rendered_mesh_1_2.png there is a black and white photo of a window with a grid
# rendered_mesh_1_3.png there is a black and white photo of a square object
# rendered_mesh_20_0.png there is a black and white photo of a plane flying in the sky
# rendered_mesh_20_1.png there is a black and white photo of a plane flying in the sky
# rendered_mesh_20_2.png there is a black stick sticking out of the ground
# rendered_mesh_20_3.png there is a black stick sticking out of the ground
# rendered_mesh_21_0.png there is a black and white photo of a plane flying in the sky
# rendered_mesh_21_1.png there is a black and white photo of a plane flying in the sky
# rendered_mesh_21_2.png there is a black stick sticking out of the ground
# rendered_mesh_21_3.png there is a black stick sticking out of the ground
# rendered_mesh_22_0.png there is a podium with a black top and a black top
# rendered_mesh_22_1.png there is a brown podium with a black top and a black top
# rendered_mesh_22_2.png there is a black podium with a microphone on it
# rendered_mesh_22_3.png there is a black podium with a microphone on it
# rendered_mesh_23_0.png close up of a black object on a white surface
# rendered_mesh_23_1.png close up of a black button
# rendered_mesh_23_2.png there is a clock that is on the wall with a red second hand
# rendered_mesh_23_3.png there is a clock that is on the wall in the room
# rendered_mesh_24_0.png there is a man riding a surfboard on the beach
# rendered_mesh_24_1.png there is a man riding a surfboard on the beach
# rendered_mesh_24_2.png there is a man riding a surfboard on the beach
# rendered_mesh_24_3.png there is a man riding a surfboard on the beach
# rendered_mesh_25_0.png there is a red plastic block with a black top
# rendered_mesh_25_1.png there is a red brick that is on a white surface
# rendered_mesh_25_2.png there is a small black brush that is on a white surface
# rendered_mesh_25_3.png there is a chocolate bar that is sitting on a white surface
# rendered_mesh_26_0.png there is a yellow tube of liquid on a white surface
# rendered_mesh_26_1.png there is a yellow tube that is sitting on a white surface
# rendered_mesh_26_2.png there is a green tube with a black top
# rendered_mesh_26_3.png there is a green tube with a black top
# rendered_mesh_27_0.png there are many tables and chairs arranged in a row
# rendered_mesh_27_1.png there are many black tables and chairs arranged in a row
# rendered_mesh_27_2.png there are many black tables and chairs in a row
# rendered_mesh_27_3.png there are many tables and chairs arranged in a row
# rendered_mesh_2_0.png there are four pieces of black plastic on a white surface
# rendered_mesh_2_1.png there are four black pieces of plastic on a white surface
# rendered_mesh_2_2.png there are four black pieces of plastic on a white surface
# rendered_mesh_2_3.png there are four black pieces of plastic that are in the air
# rendered_mesh_3_0.png there is a brown board with a brown top
# rendered_mesh_3_1.png close up of a brown board
# rendered_mesh_3_2.png there is a black television screen with a black screen on it
# rendered_mesh_3_3.png there is a picture of a flat screen tv on a white wall
# rendered_mesh_4_0.png there is a black door with a black handle on it
# rendered_mesh_4_1.png purple strips of paper are arranged in a row on a white surface
# rendered_mesh_4_2.png there is a black door with a black handle on a white wall
# rendered_mesh_4_3.png purple plastic door with a window
# rendered_mesh_5_0.png there are two black sticks sticking out of the ground
# rendered_mesh_5_1.png there are four black sticks sticking out of the ground
# rendered_mesh_5_2.png there are two black sticks sticking out of the ground
# rendered_mesh_5_3.png there are four black sticks sticking out of the ground
# rendered_mesh_6_0.png there are many pieces of chocolate on a white surface
# rendered_mesh_6_1.png there are many small pieces of chocolate on a white surface
# rendered_mesh_6_2.png there are many wooden benches arranged in a row on a white surface
# rendered_mesh_6_3.png there are many wooden benches arranged in a row on a white surface
# rendered_mesh_7_0.png there is a red tube of liquid on a white surface
# rendered_mesh_7_1.png there is a red tube that is sitting on a white surface
# rendered_mesh_7_2.png there is a red tube of lipstick
# rendered_mesh_7_3.png there is a red tube of lipstick
# rendered_mesh_8_0.png there are many small green dots in the sky
# rendered_mesh_8_1.png there are many small dots in the sky on the ground
# rendered_mesh_8_2.png there are many dots in the sky that are all over the ground
# rendered_mesh_8_3.png there are many people flying kites in the sky together
# rendered_mesh_9_0.png close up of a purple flag
# rendered_mesh_9_1.png close up of a purple flag
# rendered_mesh_9_2.png close up of a purple curtain
# rendered_mesh_9_3.png close up of a purple flag
